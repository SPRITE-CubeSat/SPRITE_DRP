# %%
'''
Demonstration of how to use calibration star code to create
1D spectral models

Remember to edit the configuration file with your
own constants before calling function
'''
     

# Import .py files
import sys

# Edit directory path to where you store your code 
sys.path.extend(["path_to_your_code"])

# Import "get_all_supernova_data" function
from call_all_calib_funcs import *
from calibration_config import star_data_path

# %%
#############
# constants #
#############

# exposure times
exposure_times = [100, 1000]

# %%
############
# HD 49798 #
############

file_name = star_data_path + "TUES_HD49798.fits"

#exposureTime of 100 seconds
call_functions_one_database(file_name, exposure_times, "TUES")
# Out:
# The S/NR at 1300A = 106.45 for an exposure time of 0.1 kilo-seconds
# The average S/NR is: 102.42 for an exposure time of 0.1 kilo-seconds
# The total SCC S/NR is: 12.58 for an exposure time of 0.1 kilo-seconds
#
# The S/NR at 1300A = 336.62 for an exposure time of 1.0 kilo-seconds
# The average S/NR is: 324.86 for an exposure time of 1.0 kilo-seconds
# The total SCC S/NR is: 40.32 for an exposure time of 1.0 kilo-seconds
#
# The average flux from 939.0 - 1409.0 Angstroms is 2e-10

# %%
#########
# GD 50 #
#########

fileFUSE = star_data_path + "FUSE_GD246.fits"
fileIUE = star_data_path + "IUE_GD246.fits"

call_functions_two_database(fileFUSE, fileIUE, exposure_times)
# Out:
# The S/NR at 1300A = 20.13 for an exposure time of 0.1 kilo-seconds
# The average S/NR is: 11.50 for an exposure time of 0.1 kilo-seconds
# The total SCC S/NR is: 4.99 for an exposure time of 0.1 kilo-seconds
#
# The S/NR at 1300A = 63.66 for an exposure time of 1.0 kilo-seconds
# The average S/NR is: 36.37 for an exposure time of 1.0 kilo-seconds
# The total SCC S/NR is: 15.78 for an exposure time of 1.0 kilo-seconds
#
# The average flux from 939.0 - 1615.0 Angstroms is 4e-12
